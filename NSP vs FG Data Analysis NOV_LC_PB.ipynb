# %%
import pandas as pd
import numpy as np
import chart_studio.plotly as py 
import plotly.graph_objs as go #importing graphical objects
#import seaborn as sns
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

from urllib.request import urlopen
import json
import plotly.express as px

from uszipcode import SearchEngine

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# c:\Users\QXZ29G0\Anaconda\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning:
#
# Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning

# %%
#open s/s and save it in dataframe
FG_PB_df = pd.read_csv('RAW_NON_COLLAPSED_LEAD_CONV_112022_BMW1.CSV')
# Out:
# C:\Users\q555834\AppData\Local\Temp\ipykernel_12432\406807393.py:2: DtypeWarning:
#
# Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
FG_PB_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2897444 entries, 0 to 2897443
# Data columns (total 31 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   #REPORT_DATE              int64
#  1   LEAD_ID                   int64
#  2   LEAD_FORWARDED_DATE       object
#  3   LEAD_RECIEVED_DATE        object
#  4   CENTER_ID                 int64
#  5   LOCATION_CODE             int64
#  6   LINEMAKE_ID               float64
#  7   SOURCE_TYPE               object
#  8   SOURCE_ORIGIN             object
#  9   SOURCE_DESC               object
#  10  SOURCE_LABEL              object
#  11  TRACKING                  object
#  12  CONV_DAYS                 float64
#  13  VEHICLE_TYPE              object
#  14  CONV_IND                  object
#  15  DUPE_IND                  object
#  16  RTL_PROCESS_DATE          object
#  17  RTL_CENTER_ID             float64
#  18  LEAD_GROUP_ID             float64
#  19  RTL_GROUP_ID              float64
# ...

# %%
FG_PB_df.head()
# Out:
#    #REPORT_DATE   LEAD_ID  LEAD_FORWARDED_DATE   LEAD_RECIEVED_DATE  \
# 0        112022  30022190  04/06/2022 08:38:07  04/06/2022 08:38:07
# 1        112022  30022191  04/06/2022 08:36:39  04/06/2022 08:36:39
# 2        112022  30022192  04/06/2022 08:37:46  04/06/2022 08:37:46
# 3        112022  30022193  04/06/2022 08:37:29  04/06/2022 08:37:29
# 4        112022  30022194  04/06/2022 08:38:44  04/06/2022 08:38:44
#
#    CENTER_ID  LOCATION_CODE  LINEMAKE_ID     SOURCE_TYPE   SOURCE_ORIGIN  \
# 0      31026              1          1.0  DEALER SOURCED  DEALER WEBSITE
# 1      36640              1          1.0  DEALER SOURCED  DEALER WEBSITE
# 2      46891              2          1.0  DEALER SOURCED  DEALER WEBSITE
# 3      46891              1          1.0  DEALER SOURCED  DEALER WEBSITE
# 4      50929              1          1.0  DEALER SOURCED  DEALER WEBSITE
#
#                           SOURCE_DESC  ... LEAD_CUSTOMER_FIRST_NAME  \
# ...

# %%
print(FG_PB_df.columns)
# Out:
# Index(['#REPORT_DATE', 'LEAD_ID', 'LEAD_FORWARDED_DATE', 'LEAD_RECIEVED_DATE',
#        'CENTER_ID', 'LOCATION_CODE', 'LINEMAKE_ID', 'SOURCE_TYPE',
#        'SOURCE_ORIGIN', 'SOURCE_DESC', 'SOURCE_LABEL', 'TRACKING', 'CONV_DAYS',
#        'VEHICLE_TYPE', 'CONV_IND', 'DUPE_IND', 'RTL_PROCESS_DATE',
#        'RTL_CENTER_ID', 'LEAD_GROUP_ID', 'RTL_GROUP_ID', 'VIN_NUMBER',
#        'LEAD_CUSTOMER_FIRST_NAME', 'LEAD_CUSTOMER_LAST_NAME',
#        'LEAD_ADDRESS_LINE1', 'LEAD_ADDRESS_LINE2', 'LEAD_ADDRESS_CITY',
#        'LEAD_ADDRESS_STATE', 'LEAD_ADDRESS_ZIP', 'LEAD_PHONE#',
#        'LEAD_EMAIL_ADDRESS', 'FS_CONV_IND'],
#       dtype='object')

# %%
FG_Centers = FG_PB_df.groupby('CENTER_ID', as_index=False)['CONV_THIS_CENTER'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12432\1438326918.py in <module>
# ----> 1 FG_Centers = FG_PB_df.groupby('CENTER_ID', as_index=False)['CONV_THIS_CENTER'].count()
#
# c:\Users\QXZ29G0\Anaconda\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1336                 stacklevel=find_stack_level(),
#    1337             )
# -> 1338         return super().__getitem__(key)
#    1339
#    1340     def _gotitem(self, key, ndim: int, subset=None):
#
# c:\Users\QXZ29G0\Anaconda\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     243         elif not getattr(self, "as_index", False):
#     244             if key not in self.obj.columns:
# --> 245                 raise KeyError(f"Column not found: {key}")
#     246             return self._gotitem(key, ndim=2)
#     247
#
# ...

# %%
FG_Centers
# Out:
#      CENTER_ID  CONV_THIS_CENTER
# 0         4497             10112
# 1         4514              9219
# 2         4618             13912
# 3         4637             13717
# 4         4660              8120
# ..         ...               ...
# 345      96628              9134
# 346      96644              2220
# 347      96717              5463
# 348      96733             11827
# 349      96774              1453
#
# [350 rows x 2 columns]

# %%
FG_df_42164 = FG_PB_df[FG_PB_df['CENTER_ID'] == 42164]

# %%
FG_df_42164_Filtered = FG_PB_df[(FG_PB_df['CENTER_ID'] == 42164)&(FG_PB_df['CONV_THIS_CENTER'] == 1)&(FG_PB_df['TRACKED_FOR_KPI_PERFORMANCE'] == 'Y')]

# %%
FG_df_42164_Filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1125 entries, 4650 to 2772444
# Data columns (total 27 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   REPORT_DATE                  1125 non-null   int64
#  1   LEAD_ID                      1125 non-null   int64
#  2   SEQUENCE_ID                  1125 non-null   int64
#  3   BMWGROUP_ID                  1125 non-null   int64
#  4   CENTER_ID                    1125 non-null   int64
#  5   CUSTOMER_NAME                1125 non-null   object
#  6   LOCATION_ID                  1125 non-null   int64
#  7   LEAD_FORWARDED_DATE          1125 non-null   object
#  8   CAMPAIGN                     1125 non-null   object
#  9   LEAD_SOURCE                  1125 non-null   object
#  10  TRACKED_FOR_KPI_PERFORMANCE  1125 non-null   object
#  11  VEHICLE_TYPE                 1125 non-null   object
#  12  RETAIL_VEHICLE_TYPE          1125 non-null   object
# ...

# %%
FG_df_42164_Filtered.to_csv('Data/CRM/NOV/FG_PB_42164.csv', index = True)

# %%
FG_PB_NODUPS_df = FG_PB_df.drop_duplicates(subset='VIN_NUMBER', keep="first")
FG_PB_NODUPS_df
# Out:
#          REPORT_DATE   LEAD_ID  SEQUENCE_ID  BMWGROUP_ID  CENTER_ID  \
# 0             102022  29175924       100000     42676997      26718
# 17            102022  29201221       100008     16158923      21234
# 30            102022  29628873       100014     19613024      42164
# 39            102022  31027869       100018     31726321      26167
# 66            102022  28517602       100028     42104629      26747
# ...              ...       ...          ...          ...        ...
# 2775733       102022  31942187      1188941     15033458      40713
# 2775739       102022  31186503       954704     22094127      66788
# 2775746       102022  31270936      1925604     34455311      10729
# 2775747       102022  29047573      1925604     42575384      10729
# 2775786       102022  29095391       550474     42617537      36021
#
#                     CUSTOMER_NAME  LOCATION_ID  LEAD_FORWARDED_DATE  \
# 0                  GALLER MICHAEL            1  01/13/2022 22:38:28
# ...

# %%
FG_df_42164_NODUPS_Filtered = FG_PB_NODUPS_df[(FG_PB_NODUPS_df['CENTER_ID'] == 42164)&(FG_PB_NODUPS_df['CONV_THIS_CENTER'] == 1)&(FG_PB_df['TRACKED_FOR_KPI_PERFORMANCE'] == 'Y')]
# Out:
# C:\Users\q555834\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
FG_df_42164_NODUPS_Filtered.to_csv('Data/CRM/NOV/FG_PB_NODUPS_42164.csv', index = True)
